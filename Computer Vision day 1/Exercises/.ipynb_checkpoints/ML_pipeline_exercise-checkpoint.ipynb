# %% [markdown]
# Using the **bankruptcy dataset** regarding company bankruptcies build a pipeline that performs the following:
#
# 1. Missing value imputation
# 2. Feature scaling
# 3. Feature selection
# 4. Model selection (HT)
#
# Which model would you choose and why?
