# %% [markdown]
# # Computer Vision, Dr. Aygul Zagidullina

# %% [markdown]
# **A walkthrough of the full process of loading data, comparing different vision models, seeing the benefits of transfer learning and data augmentation, saving/ loading models, then predicting on some data in the wild.**

# %% [markdown]
# ## Dataset

# %% [markdown]
# This Dataset contains about 5000 pictures of cats and dogs (4000 for training and 1000 for testing). Each categories will be in a separated folder, `cat-and-dog/training_set/` and `cat-and-dog/test_set` and then in sub folders `cats` and `dogs`.

# %%
# %%capture
# Let's store the location of our data in 2 variables that we can re use later

train_data_dir = "cat-and-dog-small/training_set/"
test_data_dir = "cat-and-dog-small/test_set/"

# !unzip cat-and-dog.zip

# %%
# !ls
# Out:
# cat-and-dog-small  cat-and-dog.zip  sample_data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import tensorflow as tf
import keras

# print(tf.__version__)
print(keras.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img

img = load_img(f"{train_data_dir}cats/cat.3.jpg")
x = img_to_array(img)/255  # We divide the pixel value by 255 to end up between 0 and 1

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x414>

# %%
x.shape
# Out:
# (414, 500, 3)

# %% [markdown]
# ### First ("weak") model

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers, optimizers, callbacks

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# %%
model = Sequential()

model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), input_shape = (150, 150, 3), activation="relu", padding = "same"))
model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.Conv2D(filters = 64, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.Conv2D(filters = 128, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.Flatten())

model.add(layers.Dense(64, activation="relu"))

model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  conv2d_2 (Conv2D)           (None, 150, 150, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 150, 150, 128)     73856
#
#  flatten (Flatten)           (None, 2880000)           0
#
#  dense (Dense)               (None, 64)                184320064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 184422625 (703.52 MB)
# Trainable params: 184422625 (703.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Here we didn't use any pooling layers which gave us a very high amount
#
# ---
#
# of parameters ...

# %% [markdown]
# ### First ("strong") model
#
# This time with pooling layers

# %%
model = Sequential()

model.add(layers.Rescaling(1./255, input_shape = (150, 150, 3)))
model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model.add(layers.Conv2D(filters = 64, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model.add(layers.Conv2D(filters = 128, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model.add(layers.Flatten())

# Here we flatten our data to end up with just one dimension

model.add(layers.Dense(64, activation="relu"))

model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation="sigmoid"))

# And we perform the prediction using sigmoid

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 32)        0
#  D)
#
#  conv2d_5 (Conv2D)           (None, 75, 75, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 38, 38, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 38, 38, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 19, 19, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_2 (Dense)             (None, 64)                819264
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 921825 (3.52 MB)
# Trainable params: 921825 (3.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# With pooling layers with drastically reduced the amount of parameters from 165,286,113 to 504,033

# %%
adam = optimizers.Adam(learning_rate = 0.001)
model.compile(loss='binary_crossentropy',
              optimizer= adam,
              metrics=['accuracy'])

# %%
batch_size = 64

# %% [markdown]
# Here, we'll create a `Tensorflow Datasets` object.
# This will allow us to:
#
#
# *   Grab images from our directory batch by batch, we won't load the FULL data at the same time
# *   Reshape all the images to our desired input shape, 150x150 in this notebook

# %% [markdown]
# We have to specify different things:
#
#
# *   Where the data is located (that's why we saved the folder name in a variable)
# *   The target size to resize our images so they fit our model
# *   The Batch size
# *   The "label mode", here we say binary, and the classes will be infered based on the folders name. It will chose cat = 0 and dog = 1
# *   Here the labels are inferred based on the folder structure

# %%
train_ds = image_dataset_from_directory(
  train_data_dir,
  labels = "inferred",
  label_mode = "binary",
  seed=123,
  image_size=(150, 150),
  batch_size=batch_size)

# We define a second one for the test data

val_ds = image_dataset_from_directory(
  test_data_dir,
  labels = "inferred",
  label_mode = "binary",
  seed=123,
  image_size=(150, 150),
  batch_size=batch_size)
# Out:
# Found 4004 files belonging to 2 classes.
# Found 1012 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cats', 'dogs']

# %% [markdown]
# Here we'll create our callbacks. Those functions will be called at the end of every single epoch.
# We'll use:
#
#
# *   `ModelCheckpoint` to save the best version of our model after every epoch
# *   `ReduceLROnPlateau` to reduce the `learning_rate` if the model doesn't get better after a few epochs
# *   `EarlyStopping` to stop the training after a certain time if it's not improving

# %%
MODEL = "model_1"

modelCheckpoint = callbacks.ModelCheckpoint("{}.h5".format(MODEL), monitor="val_loss", verbose=0, save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss", factor = 0.1, patience=3, verbose=1, min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)

# %%
# %%time
history = model.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper])
# Out:
# Epoch 1/30
# 63/63 [==============================] - 15s 109ms/step - loss: 0.6939 - accuracy: 0.5160 - val_loss: 0.6810 - val_accuracy: 0.6028 - lr: 0.0010
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/30
# 63/63 [==============================] - 7s 107ms/step - loss: 0.6781 - accuracy: 0.5597 - val_loss: 0.6238 - val_accuracy: 0.6581 - lr: 0.0010
# Epoch 3/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.6413 - accuracy: 0.6321 - val_loss: 0.5938 - val_accuracy: 0.6729 - lr: 0.0010
# Epoch 4/30
# 63/63 [==============================] - 7s 104ms/step - loss: 0.5879 - accuracy: 0.6928 - val_loss: 0.5768 - val_accuracy: 0.6986 - lr: 0.0010
# Epoch 5/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.5815 - accuracy: 0.6983 - val_loss: 0.5331 - val_accuracy: 0.7569 - lr: 0.0010
# Epoch 6/30
# 63/63 [==============================] - 6s 93ms/step - loss: 0.5422 - accuracy: 0.7200 - val_loss: 0.5819 - val_accuracy: 0.7184 - lr: 0.0010
# Epoch 7/30
# 63/63 [==============================] - 6s 79ms/step - loss: 0.5155 - accuracy: 0.7473 - val_loss: 0.5031 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 8/30
# 63/63 [==============================] - 8s 116ms/step - loss: 0.5018 - accuracy: 0.7575 - val_loss: 0.4909 - val_accuracy: 0.7796 - lr: 0.0010
# Epoch 9/30
# 63/63 [==============================] - 5s 77ms/step - loss: 0.4749 - accuracy: 0.7795 - val_loss: 0.4919 - val_accuracy: 0.7836 - lr: 0.0010
# Epoch 10/30
# 63/63 [==============================] - 7s 99ms/step - loss: 0.4698 - accuracy: 0.7810 - val_loss: 0.4956 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 11/30
# 62/63 [============================>.] - ETA: 0s - loss: 0.4277 - accuracy: 0.8122
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 63/63 [==============================] - 5s 77ms/step - loss: 0.4283 - accuracy: 0.8114 - val_loss: 0.4947 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 12/30
# 63/63 [==============================] - 5s 79ms/step - loss: 0.3796 - accuracy: 0.8272 - val_loss: 0.4586 - val_accuracy: 0.8034 - lr: 1.0000e-04
# Epoch 13/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.3475 - accuracy: 0.8454 - val_loss: 0.4608 - val_accuracy: 0.8083 - lr: 1.0000e-04
# Epoch 14/30
# 63/63 [==============================] - 5s 77ms/step - loss: 0.3424 - accuracy: 0.8526 - val_loss: 0.4593 - val_accuracy: 0.8063 - lr: 1.0000e-04
# Epoch 15/30
# 62/63 [============================>.] - ETA: 0s - loss: 0.3329 - accuracy: 0.8558
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 63/63 [==============================] - 5s 79ms/step - loss: 0.3328 - accuracy: 0.8561 - val_loss: 0.4591 - val_accuracy: 0.8083 - lr: 1.0000e-04
# Epoch 16/30
# 63/63 [==============================] - 5s 79ms/step - loss: 0.3264 - accuracy: 0.8584 - val_loss: 0.4611 - val_accuracy: 0.8083 - lr: 1.0000e-05
# Epoch 17/30
# 63/63 [==============================] - 6s 95ms/step - loss: 0.3267 - accuracy: 0.8611 - val_loss: 0.4614 - val_accuracy: 0.8083 - lr: 1.0000e-05
# Epoch 18/30
# 62/63 [============================>.] - ETA: 0s - loss: 0.3226 - accuracy: 0.8609
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 63/63 [==============================] - 5s 77ms/step - loss: 0.3226 - accuracy: 0.8609 - val_loss: 0.4611 - val_accuracy: 0.8083 - lr: 1.0000e-05
# Epoch 19/30
# 63/63 [==============================] - 6s 78ms/step - loss: 0.3228 - accuracy: 0.8649 - val_loss: 0.4611 - val_accuracy: 0.8083 - lr: 1.0000e-06
# Epoch 20/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.3221 - accuracy: 0.8619 - val_loss: 0.4614 - val_accuracy: 0.8083 - lr: 1.0000e-06
# Epoch 21/30
# 62/63 [============================>.] - ETA: 0s - loss: 0.3220 - accuracy: 0.8609
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 63/63 [==============================] - 6s 90ms/step - loss: 0.3219 - accuracy: 0.8609 - val_loss: 0.4613 - val_accuracy: 0.8083 - lr: 1.0000e-06
# Epoch 22/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.3173 - accuracy: 0.8689 - val_loss: 0.4613 - val_accuracy: 0.8083 - lr: 1.0000e-07
# CPU times: user 3min 21s, sys: 16.9 s, total: 3min 38s
# Wall time: 2min 55s

# %%
def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

# %%
def plot_compare_history(history, name_history, history_1, name_history_1):

    fig, ax = plt.subplots(1, 2, figsize=(15,5))

    ax[0].set_title('loss')

    ax[0].plot(history.epoch, history.history["loss"], label="Train loss " + name_history)
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss " + name_history)

    ax[0].plot(history_1.epoch, history_1.history["loss"], label="Train loss " + name_history_1)
    ax[0].plot(history_1.epoch, history_1.history["val_loss"], label="Validation loss " + name_history_1)

    ax[1].set_title('Accuracy')

    ax[1].plot(history.epoch, history.history["accuracy"], label="Train Accuracy " + name_history)
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy " + name_history)

    ax[1].plot(history_1.epoch, history_1.history["accuracy"], label="Train Accuracy " + name_history_1)
    ax[1].plot(history_1.epoch, history_1.history["val_accuracy"], label="Validation Accuracy " + name_history_1)

    ax[0].legend()
    ax[1].legend()

# %%
plot_history(history)

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ![Texte alternatif…](https://cdn-images-1.medium.com/max/1020/1*C8hNiOqur4OJyEZmC7OnzQ.png)

# %% [markdown]
# ### Second model with Data Augmentation

# %%
# We'll use a model with the same convolutional layers, but we'll add Augmentation layers before that

model_2 = Sequential()

model_2.add(layers.Rescaling(1./255, input_shape = (150, 150, 3)))

# Data Augmentation Layers

model_2.add(layers.RandomFlip("horizontal"))
model_2.add(layers.RandomZoom(0.1))
model_2.add(layers.RandomTranslation(0.2, 0.2))
model_2.add(layers.RandomRotation(0.1))


# Convolutional Layers

model_2.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_2.add(layers.Conv2D(filters = 32, kernel_size = (3,3), input_shape = (150, 150, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_2.add(layers.Conv2D(filters = 64, kernel_size = (3,3), input_shape = (150, 150, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_2.add(layers.Conv2D(filters = 128, kernel_size = (3,3), input_shape = (150, 150, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_2.add(layers.Flatten())

model_2.add(layers.Dense(64, activation="relu"))

model_2.add(layers.Dropout(0.5))

model_2.add(layers.Dense(1, activation="sigmoid"))

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)       0
#
#  random_flip (RandomFlip)    (None, 150, 150, 3)       0
#
#  random_zoom (RandomZoom)    (None, 150, 150, 3)       0
#
#  random_translation (Random  (None, 150, 150, 3)       0
#  Translation)
#
#  random_rotation (RandomRot  (None, 150, 150, 3)       0
#  ation)
#
#  conv2d_8 (Conv2D)           (None, 150, 150, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 75, 75, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 38, 38, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 38, 38, 64)        18496
#
#  max_pooling2d_6 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 19, 19, 128)       73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 12800)             0
#
#  dense_4 (Dense)             (None, 64)                819264
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 921825 (3.52 MB)
# Trainable params: 921825 (3.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
adam = optimizers.Adam(learning_rate=0.001)

model_2.compile(loss='binary_crossentropy',
              optimizer= adam,
              metrics=['accuracy'])

# %%
MODEL = "model_2"

modelCheckpoint = callbacks.ModelCheckpoint("{}.h5".format(MODEL), monitor="val_loss", verbose=0, save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss", factor = 0.1, patience=3, verbose=1, min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)

# %%
# %%time
history_2 = model_2.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper]
        )
# Out:
# Epoch 1/30
# 63/63 [==============================] - 9s 104ms/step - loss: 0.6950 - accuracy: 0.5035 - val_loss: 0.6916 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/30
# 63/63 [==============================] - 6s 81ms/step - loss: 0.6914 - accuracy: 0.5262 - val_loss: 0.6915 - val_accuracy: 0.5148 - lr: 0.0010
# Epoch 3/30
# 63/63 [==============================] - 8s 112ms/step - loss: 0.6859 - accuracy: 0.5524 - val_loss: 0.6750 - val_accuracy: 0.6413 - lr: 0.0010
# Epoch 4/30
# 63/63 [==============================] - 6s 89ms/step - loss: 0.6789 - accuracy: 0.5769 - val_loss: 0.6430 - val_accuracy: 0.6482 - lr: 0.0010
# Epoch 5/30
# 63/63 [==============================] - 6s 89ms/step - loss: 0.6517 - accuracy: 0.6256 - val_loss: 0.6357 - val_accuracy: 0.6403 - lr: 0.0010
# Epoch 6/30
# 63/63 [==============================] - 6s 82ms/step - loss: 0.6337 - accuracy: 0.6469 - val_loss: 0.6123 - val_accuracy: 0.7075 - lr: 0.0010
# Epoch 7/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.6226 - accuracy: 0.6658 - val_loss: 0.6157 - val_accuracy: 0.6581 - lr: 0.0010
# Epoch 8/30
# 63/63 [==============================] - 7s 112ms/step - loss: 0.6220 - accuracy: 0.6496 - val_loss: 0.5803 - val_accuracy: 0.6996 - lr: 0.0010
# Epoch 9/30
# 63/63 [==============================] - 5s 79ms/step - loss: 0.5969 - accuracy: 0.6868 - val_loss: 0.6017 - val_accuracy: 0.7006 - lr: 0.0010
# Epoch 10/30
# 63/63 [==============================] - 7s 113ms/step - loss: 0.5939 - accuracy: 0.6953 - val_loss: 0.5742 - val_accuracy: 0.6907 - lr: 0.0010
# Epoch 11/30
# 63/63 [==============================] - 6s 82ms/step - loss: 0.5999 - accuracy: 0.6781 - val_loss: 0.5589 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 12/30
# 63/63 [==============================] - 6s 96ms/step - loss: 0.5681 - accuracy: 0.7158 - val_loss: 0.5638 - val_accuracy: 0.7085 - lr: 0.0010
# Epoch 13/30
# 63/63 [==============================] - 6s 82ms/step - loss: 0.5637 - accuracy: 0.7073 - val_loss: 0.5381 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 14/30
# 63/63 [==============================] - 7s 102ms/step - loss: 0.5549 - accuracy: 0.7210 - val_loss: 0.5797 - val_accuracy: 0.6818 - lr: 0.0010
# Epoch 15/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.5526 - accuracy: 0.7208 - val_loss: 0.5654 - val_accuracy: 0.6937 - lr: 0.0010
# Epoch 16/30
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5507 - accuracy: 0.7285 - val_loss: 0.4831 - val_accuracy: 0.7737 - lr: 0.0010
# Epoch 17/30
# 63/63 [==============================] - 5s 81ms/step - loss: 0.5354 - accuracy: 0.7350 - val_loss: 0.5005 - val_accuracy: 0.7717 - lr: 0.0010
# Epoch 18/30
# 63/63 [==============================] - 7s 98ms/step - loss: 0.5257 - accuracy: 0.7455 - val_loss: 0.4906 - val_accuracy: 0.7846 - lr: 0.0010
# Epoch 19/30
# 63/63 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.7475
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 63/63 [==============================] - 6s 85ms/step - loss: 0.5280 - accuracy: 0.7475 - val_loss: 0.5190 - val_accuracy: 0.7312 - lr: 0.0010
# Epoch 20/30
# 63/63 [==============================] - 7s 100ms/step - loss: 0.5085 - accuracy: 0.7557 - val_loss: 0.4683 - val_accuracy: 0.7895 - lr: 1.0000e-04
# Epoch 21/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.4906 - accuracy: 0.7720 - val_loss: 0.4658 - val_accuracy: 0.7806 - lr: 1.0000e-04
# Epoch 22/30
# 63/63 [==============================] - 7s 106ms/step - loss: 0.5008 - accuracy: 0.7687 - val_loss: 0.4700 - val_accuracy: 0.7717 - lr: 1.0000e-04
# Epoch 23/30
# 63/63 [==============================] - 6s 82ms/step - loss: 0.4859 - accuracy: 0.7630 - val_loss: 0.4575 - val_accuracy: 0.7846 - lr: 1.0000e-04
# Epoch 24/30
# 63/63 [==============================] - 6s 89ms/step - loss: 0.4901 - accuracy: 0.7685 - val_loss: 0.4542 - val_accuracy: 0.7866 - lr: 1.0000e-04
# Epoch 25/30
# 63/63 [==============================] - 5s 79ms/step - loss: 0.4792 - accuracy: 0.7762 - val_loss: 0.4572 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 26/30
# 63/63 [==============================] - 7s 104ms/step - loss: 0.4803 - accuracy: 0.7710 - val_loss: 0.4459 - val_accuracy: 0.7984 - lr: 1.0000e-04
# Epoch 27/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.4729 - accuracy: 0.7772 - val_loss: 0.4476 - val_accuracy: 0.7964 - lr: 1.0000e-04
# Epoch 28/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.4775 - accuracy: 0.7735 - val_loss: 0.4382 - val_accuracy: 0.8083 - lr: 1.0000e-04
# Epoch 29/30
# 63/63 [==============================] - 7s 102ms/step - loss: 0.4764 - accuracy: 0.7790 - val_loss: 0.4435 - val_accuracy: 0.8004 - lr: 1.0000e-04
# Epoch 30/30
# 63/63 [==============================] - 6s 93ms/step - loss: 0.4680 - accuracy: 0.7772 - val_loss: 0.4451 - val_accuracy: 0.7964 - lr: 1.0000e-04
# CPU times: user 4min 33s, sys: 21.8 s, total: 4min 55s
# Wall time: 3min 43s

# %%
plot_history(history_2)

# %%
plot_compare_history(history, "Basic CNN", history_2, "Data Augmentation")

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# ![Texte alternatif…](https://cdn-images-1.medium.com/max/1600/1*9GTEzcO8KxxrfutmtsPs3Q.png)

# %% [markdown]
# ![Texte alternatif…](https://www.researchgate.net/profile/Francesco-Orabona/publication/221363182/figure/fig1/AS:276504308142080@1442935172550/Three-ways-in-which-transfer-might-improve-learning-19.png)

# %% [markdown]
# ### Third model with Transfer Learning and Data Augmentation

# %%
data_augmentation = Sequential()

data_augmentation.add(layers.RandomFlip("horizontal"))
data_augmentation.add(layers.RandomZoom(0.1))
data_augmentation.add(layers.RandomTranslation(0.2, 0.2))
data_augmentation.add(layers.RandomRotation(0.1))

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model

# %%
base_model = VGG16(weights = "imagenet", include_top = False, input_shape = (150, 150, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# First step is to initialize the VGG16 model but without the top as we'll adapt it to our problem

inputs = layers.Input(shape = (150, 150, 3))

x = data_augmentation(inputs) # We still have our data augmentation layers
x = preprocess_input(x) # Then a preprocessing layer specifically designed for the VGG16
x = base_model(x) # Then our transfer learning model

x = layers.Flatten()(x) # Followed by our custom dense layers, tailored to our binary task

x = layers.Dense(128, activation = "relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(64, activation = "relu")(x)
x = layers.Dropout(0.3)(x)
pred = layers.Dense(1, activation = "sigmoid")(x)

# We use the keras Functional API to create our keras model

model_3 = Model(inputs = inputs , outputs = pred)

# And we freeze the VGG16 model

base_model.trainable = False

#for layer in base_model.layers[:10]:
#  layer.trainable = False

# %%
model_3.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  sequential_3 (Sequential)   (None, 150, 150, 3)       0
#
#  tf.__operators__.getitem (  (None, 150, 150, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 150, 150, 3)       0
#  )
#
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 128)               1048704
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 15771713 (60.16 MB)
# Trainable params: 1057025 (4.03 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
adam = optimizers.Adam(learning_rate = 0.001)
model_3.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# %%
MODEL = "model_3"

modelCheckpoint = callbacks.ModelCheckpoint("{}.h5".format(MODEL), monitor="val_loss", verbose=0, save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss", factor = 0.1, patience=3, verbose=1, min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)

# %%
# %%time
history_3 = model_3.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper])
# Out:
# Epoch 1/30
# 63/63 [==============================] - 30s 334ms/step - loss: 1.2715 - accuracy: 0.8324 - val_loss: 0.1711 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 2/30
# 63/63 [==============================] - 11s 168ms/step - loss: 0.3775 - accuracy: 0.9028 - val_loss: 0.1862 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 3/30
# 63/63 [==============================] - 11s 173ms/step - loss: 0.2686 - accuracy: 0.8994 - val_loss: 0.1634 - val_accuracy: 0.9654 - lr: 0.0010
# Epoch 4/30
# 63/63 [==============================] - 12s 177ms/step - loss: 0.2572 - accuracy: 0.9018 - val_loss: 0.1221 - val_accuracy: 0.9723 - lr: 0.0010
# Epoch 5/30
# 63/63 [==============================] - 11s 169ms/step - loss: 0.2450 - accuracy: 0.9131 - val_loss: 0.1231 - val_accuracy: 0.9763 - lr: 0.0010
# Epoch 6/30
# 63/63 [==============================] - 11s 168ms/step - loss: 0.2259 - accuracy: 0.9121 - val_loss: 0.1503 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 7/30
# 63/63 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9163
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 63/63 [==============================] - 11s 169ms/step - loss: 0.2371 - accuracy: 0.9163 - val_loss: 0.1343 - val_accuracy: 0.9713 - lr: 0.0010
# Epoch 8/30
# 63/63 [==============================] - 11s 170ms/step - loss: 0.1977 - accuracy: 0.9196 - val_loss: 0.1282 - val_accuracy: 0.9753 - lr: 1.0000e-04
# Epoch 9/30
# 63/63 [==============================] - 11s 168ms/step - loss: 0.1879 - accuracy: 0.9261 - val_loss: 0.1253 - val_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 10/30
# 63/63 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.9311
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 63/63 [==============================] - 11s 175ms/step - loss: 0.1801 - accuracy: 0.9311 - val_loss: 0.1236 - val_accuracy: 0.9733 - lr: 1.0000e-04
# Epoch 11/30
# 63/63 [==============================] - 14s 212ms/step - loss: 0.1967 - accuracy: 0.9198 - val_loss: 0.1232 - val_accuracy: 0.9733 - lr: 1.0000e-05
# Epoch 12/30
# 63/63 [==============================] - 11s 175ms/step - loss: 0.1784 - accuracy: 0.9243 - val_loss: 0.1234 - val_accuracy: 0.9733 - lr: 1.0000e-05
# Epoch 13/30
# 63/63 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9328
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 63/63 [==============================] - 14s 212ms/step - loss: 0.1616 - accuracy: 0.9328 - val_loss: 0.1238 - val_accuracy: 0.9743 - lr: 1.0000e-05
# Epoch 14/30
# 63/63 [==============================] - 12s 176ms/step - loss: 0.1624 - accuracy: 0.9361 - val_loss: 0.1238 - val_accuracy: 0.9743 - lr: 1.0000e-06
# CPU times: user 2min 20s, sys: 16.6 s, total: 2min 36s
# Wall time: 3min 10s

# %%
plot_history(history_3)

# %%
plot_compare_history(history, "Basic CNN", history_3, "Transfer Learning")

# %%
plot_compare_history(history_2, "Augmentation", history_3, "Augmentation + Transfer Learning")

# %% [markdown]
# ## Save and use the model

# %%
model_3.save("model_3.h5")

# %%
from tensorflow.keras.models import load_model

model_3 = load_model("model_3.h5")

# %%
from PIL import Image
import requests
from io import BytesIO

def getImage(url):

  # Grabs an image based on its URL, and resize it

  response = requests.get(url)
  img = Image.open(BytesIO(response.content))
  plt.imshow(img)
  img = img.resize((150, 150))
  return img

def predictImage(url, model):

  # Takes an imafe and a model

  img = getImage(url)
  img = img_to_array(img)
  img = img.reshape((-1, 150, 150, 3))
  res = model.predict(img)[0][0]
  if(res < 0.5):
    animal = "cat"
    prob = 1-res
  if(res >= 0.5):
    animal = "dog"
    prob = res

  print("Animal : ", animal)
  print("probability = ",prob)

# %%
cat = "https://www.wikichat.fr/wp-content/uploads/sites/2/comment-soigner-une-plaie-dun-chat.jpg"
cat2 = "http://create.votreveterinaire.com/adm/webmaster/_empty/upload/chat_surpris.jpg"


dog = "https://images.sudouest.fr/2018/04/14/5ace461a66a4bd2b1780a0dd/widescreen/1000x500/on-ignore-si-le-chihuahua-a-deserte-ou-non-les-locaux-de-la-clinique.jpg?v1"
dog2 = "https://ds1.static.rtbf.be/article/image/370x208/7/8/f/a20f02dfccd07952da54a7f9a82b3e89-1524657315.jpg"

# %%
predictImage(cat, model_3)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Animal :  cat
# probability =  0.999999999999958

# %%
predictImage(cat2, model_3)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Animal :  cat
# probability =  1.0

# %%
predictImage(dog, model_3)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Animal :  dog
# probability =  0.9999993

# %%
predictImage(dog2, model_3)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Animal :  dog
# probability =  1.0
